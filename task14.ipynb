# %%
import numpy as np
import pandas as pd
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

df = pd.read_csv("2004-2021.csv",sep = "\t")

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
df.columns
# Out:
# Index(['DATA INICIAL', 'DATA FINAL', 'REGIÃO', 'ESTADO', 'PRODUTO',
#        'NÚMERO DE POSTOS PESQUISADOS', 'UNIDADE DE MEDIDA',
#        'PREÇO MÉDIO REVENDA', 'DESVIO PADRÃO REVENDA', 'PREÇO MÍNIMO REVENDA',
#        'PREÇO MÁXIMO REVENDA', 'MARGEM MÉDIA REVENDA',
#        'COEF DE VARIAÇÃO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO',
#        'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO',
#        'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO'],
#       dtype='str')

# %%
df.rename(columns = {"DATA INICIAL":"START DATE"},inplace = True)

# %%
old_name = ['START DATE', 'DATA FINAL', 'REGIÃO', 'ESTADO', 'PRODUTO',
       'NÚMERO DE POSTOS PESQUISADOS', 'UNIDADE DE MEDIDA',
       'PREÇO MÉDIO REVENDA', 'DESVIO PADRÃO REVENDA', 'PREÇO MÍNIMO REVENDA',
       'PREÇO MÁXIMO REVENDA', 'MARGEM MÉDIA REVENDA',
       'COEF DE VARIAÇÃO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO',
       'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO',
       'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']

# %%
new_name = [
    'START DATE', 
    'END DATE', 
    'REGION', 
    'STATE', 
    'PRODUCT',
    'NUMBER OF STATIONS SURVEYED', 
    'UNIT OF MEASUREMENT',
    'AVERAGE RESALE PRICE', 
    'RESALE STANDARD DEVIATION', 
    'MINIMUM RESALE PRICE',
    'MAXIMUM RESALE PRICE', 
    'AVERAGE RESALE MARGIN',
    'RESALE COEFFICIENT OF VARIATION', 
    'AVERAGE DISTRIBUTION PRICE',
    'DISTRIBUTION STANDARD DEVIATION', 
    'MINIMUM DISTRIBUTION PRICE',
    'MAXIMUM DISTRIBUTION PRICE', 
    'DISTRIBUTION COEFFICIENT OF VARIATION'
]

# %%
print(len(df.columns))
# Out:
# 18

# %%
for i in range(len(df.columns)):
    df.rename(columns = {old_name[i]:new_name[i]},inplace = True)

# %%
df.head()
# Out:
#    START DATE    END DATE        REGION               STATE           PRODUCT  \
# 0  2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 1  2004-05-09  2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2  2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 3  2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 4  2004-05-09  2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#    NUMBER OF STATIONS SURVEYED UNIT OF MEASUREMENT  AVERAGE RESALE PRICE  \
# 0                          127                R$/l                 1.288
# 1                          387                R$/l                 1.162
# 2                          192                R$/l                 1.389
# 3                          162                R$/l                 1.262
# 4                          103                R$/l                 1.181
#
# ...

# %%
df.columns
# Out:
# Index(['START DATE', 'END DATE', 'REGION', 'STATE', 'PRODUCT',
#        'NUMBER OF STATIONS SURVEYED', 'UNIT OF MEASUREMENT',
#        'AVERAGE RESALE PRICE', 'RESALE STANDARD DEVIATION',
#        'MINIMUM RESALE PRICE', 'MAXIMUM RESALE PRICE', 'AVERAGE RESALE MARGIN',
#        'RESALE COEFFICIENT OF VARIATION', 'AVERAGE DISTRIBUTION PRICE',
#        'DISTRIBUTION STANDARD DEVIATION', 'MINIMUM DISTRIBUTION PRICE',
#        'MAXIMUM DISTRIBUTION PRICE', 'DISTRIBUTION COEFFICIENT OF VARIATION'],
#       dtype='str')

# %%
df.drop('UNIT OF MEASUREMENT' , axis = 1 , inplace = True)

# %%
# df.rename(columns = {"DATA INICIAL":"START DATE"},inplace = True)

# %%
df
# Out:
#         START DATE    END DATE        REGION               STATE  \
# 0       2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1       2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2       2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3       2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4       2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...            ...         ...           ...                 ...
# 120818  2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819  2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820  2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821  2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822  2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUCT  NUMBER OF STATIONS SURVEYED  AVERAGE RESALE PRICE  \
# 0       ETANOL HIDRATADO                          127                 1.288
# ...

# %%
import pandas as pd
df = pd.read_csv("2004-2021.csv")
df.drop(columns=["UNIT OF MEASUREMENT"],axis=1)

# %%
df.drop(columns = {"UNIT OF MEASUREMENT"},inplace = True)

# %%
df.drop(columns = ({"UNIT OF MEASUREMENT"}),inplace=True)

# %%
df.head()

# %%
df.drop("UNIT OF MEASUREMENT",axis=1,inplace=True)
df.head()

# %%
df.drop("RESALE STANDARD DEVIATION",axis=1,inplace=True)
df.head()
# Out:
#    START DATE    END DATE        REGION               STATE           PRODUCT  \
# 0  2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 1  2004-05-09  2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2  2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 3  2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 4  2004-05-09  2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#    NUMBER OF STATIONS SURVEYED  AVERAGE RESALE PRICE  MINIMUM RESALE PRICE  \
# 0                          127                 1.288                  1.19
# 1                          387                 1.162                  0.89
# 2                          192                 1.389                  1.18
# 3                          162                 1.262                  1.09
# 4                          103                 1.181                  1.05
#
# ...
